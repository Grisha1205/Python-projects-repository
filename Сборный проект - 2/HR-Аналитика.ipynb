# %% [markdown]
# **Описание проекта**
#
# HR-аналитики компании «Работа с заботой» помогают бизнесу оптимизировать управление персоналом: бизнес предоставляет данные, а аналитики предлагают, как избежать финансовых потерь и оттока сотрудников. В этом HR-аналитикам пригодится машинное обучение, с помощью которого получится быстрее и точнее отвечать на вопросы бизнеса.
#
# Компания предоставила данные с характеристиками сотрудников компании. Среди них — уровень удовлетворённости сотрудника работой в компании. Эту информацию получили из форм обратной связи: сотрудники заполняют тест-опросник, и по его результатам рассчитывается доля их удовлетворённости от 0 до 1, где 0 — совершенно неудовлетворён, 1 — полностью удовлетворён.
#
# Собирать данные такими опросниками не так легко: компания большая, и всех сотрудников надо сначала оповестить об опросе, а затем проследить, что все его прошли.
# У вас будет несколько задач. Первая — построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.
#
# Почему бизнесу это важно: удовлетворённость работой напрямую влияет на отток сотрудников. А предсказание оттока — одна из важнейших задач HR-аналитиков. Внезапные увольнения несут в себе риски для компании, особенно если уходит важный сотрудник.
# Ваша вторая задача — построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании.
#
# Теперь расскажем подробнее о задачах.

# %% [markdown]
# **Задача 1: предсказание уровня удовлетворённости сотрудника**
#
# Для этой задачи заказчик предоставил данные с признаками:
#
# * id — уникальный идентификатор сотрудника;
# * dept — отдел, в котором работает сотрудник;
# * level — уровень занимаемой должности;
# * workload — уровень загруженности сотрудника;
# * employment_years — длительность работы в компании (в годах);
# * last_year_promo — показывает, было ли повышение за последний год;
# * last_year_violations — показывает, нарушал ли сотрудник трудовой договор за последний год;
# * supervisor_evaluation — оценка качества работы сотрудника, которую дал руководитель;
# * salary — ежемесячная зарплата сотрудника;
# * job_satisfaction_rate — уровень удовлетворённости сотрудника работой в компании, целевой признак.
#
# Тренировочная выборка:
#
# * train_job_satisfaction_rate.csv
#
# Входные признаки тестовой выборки:
#
# * test_features.csv
#
# Целевой признак тестовой выборки:
#
# * test_target_job_satisfaction_rate.csv

# %% [markdown]
# **Задача 2: предсказание увольнения сотрудника из компании**
#
# Для этой задачи вы можете использовать те же входные признаки, что и в предыдущей задаче. Однако целевой признак отличается: это quit — увольнение сотрудника из компании.
#
# Тренировочная выборка:
#
# * train_quit.csv
#
# Входные признаки тестовой выборки те же, что и в прошлой задаче:
#
# * test_features.csv
#
# Целевой признак тестовой выборки:
#
# * test_target_quit.csv

# %% [markdown]
# План работ представлен в меню Table of Contents

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Задача-1:-предсказание-уровня-удовлетворённости-сотрудника" data-toc-modified-id="Задача-1:-предсказание-уровня-удовлетворённости-сотрудника-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Задача 1: предсказание уровня удовлетворённости сотрудника</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Обучение моделей</a></span></li><li><span><a href="#Оформление-выводов" data-toc-modified-id="Оформление-выводов-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Оформление выводов</a></span></li></ul></li><li><span><a href="#Задача-2:-предсказание-увольнения-сотрудника-из-компании" data-toc-modified-id="Задача-2:-предсказание-увольнения-сотрудника-из-компании-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Задача 2: предсказание увольнения сотрудника из компании</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Портрет-уволившегося-сотрудника" data-toc-modified-id="Портрет-уволившегося-сотрудника-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span><strong>Портрет уволившегося сотрудника</strong></a></span></li></ul></li><li><span><a href="#Добавление-нового-входного-признака" data-toc-modified-id="Добавление-нового-входного-признака-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Добавление нового входного признака</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Обучение-модели" data-toc-modified-id="Обучение-модели-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Обучение модели</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# ## Задача 1: предсказание уровня удовлетворённости сотрудника

# %% [markdown]
# ### Загрузка данных

# %%
# !pip install -U \
    scikit-learn==1.3.2 -q \
    imbalanced-learn==0.11.0 -q\
    matplotlib -q\
    seaborn -q\
    pandas -q\
    numpy -q\
    phik -q

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os 
import requests

from sklearn.metrics import roc_auc_score
from sklearn.metrics import make_scorer

from imblearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from phik.report import correlation_report, plot_correlation_matrix

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, LabelEncoder
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import LabelEncoder

from sklearn.impute import SimpleImputer
from sklearn.model_selection import RandomizedSearchCV, cross_val_score

from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, plot_tree
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.dummy import DummyRegressor, DummyClassifier
from catboost import CatBoostRegressor

from statsmodels.stats.proportion import proportions_ztest

# %%
def load_dataset(file_path):
    url = f'https://code.s3.yandex.net/datasets/{os.path.basename(file_path)}'
    
    if os.path.exists(file_path):
        return pd.read_csv(file_path)
    elif requests.get(url).status_code == 200:
        return pd.read_csv(url)
    else:
        print(f'Файл {file_path} не найден')
        return None

# Загрузка датасетов
train_job_satisfaction = load_dataset('/datasets/train_job_satisfaction_rate.csv')
test_features = load_dataset('/datasets/test_features.csv')
test_target_job_satisfaction = load_dataset('/datasets/test_target_job_satisfaction_rate.csv')

# %%
display(train_job_satisfaction.head())
train_job_satisfaction.info()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  155278       sales  junior   medium                 2              no
# 1  653870          hr  junior     high                 2              no
# 2  184592       sales  junior      low                 1              no
# 3  171431  technology  junior      low                 4              no
# 4  693419          hr  junior   medium                 1              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      1   24000                   0.58
# 1                   no                      5   38400                   0.76
# 2                   no                      2   12000                   0.11
# 3                   no                      2   18000                   0.37
# 4                   no                      3   22800                   0.20
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# Объем данных:
#
# * 4000 строк (сотрудников)
# * 10 столбцов
#
# Пропуски:
#
# * dept — 6 (0.15%)
# * level — 4 (0.1%)
#
# Типы признаков
#
# Числовые:
#
# * id — уникальный ID (int64)
# * employment_years — стаж (int64)
# * supervisor_evaluation — оценка (int64)
# * salary — зарплата (int64)
# * job_satisfaction_rate — удовлетворенность (float64)
#
# Категориальные:
#
# * dept — отдел
# * level — уровень
# * workload — нагрузка
# * last_year_promo — повышение
# * last_year_violations — нарушения

# %%
display(test_features.head())
test_features.info()
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary
# 0                   no                      5   28800
# 1                   no                      4   30000
# 2                   no                      4   19200
# 3                   no                      4   19200
# 4                   no                      5   40800
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ...

# %% [markdown]
# Общий объем данных:
#
# * 2000 строк (записей о сотрудниках)
# * 9 столбцов (характеристик)
#
# Пропуски:
#
# * dept: 2 пропуска
# * level: 1 пропуск
#
# Типы данных:
#
# Числовые признаки (int64):
#
# * id (уникальный идентификатор)
# * employment_years (стаж работы в годах)
# * supervisor_evaluation (оценка руководителя, целое число)
# * salary (зарплата)
#
# Категориальные признаки (object):
#
# * dept (отдел)
# * level (уровень)
# * workload (нагрузка)
# * last_year_promo (было ли повышение)
# * last_year_violations (нарушения)

# %%
display(test_target_job_satisfaction.head())
test_target_job_satisfaction.info()
# Out:
#        id  job_satisfaction_rate
# 0  130604                   0.74
# 1  825977                   0.75
# 2  418490                   0.60
# 3  555320                   0.72
# 4  826430                   0.08
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB

# %% [markdown]
# Объем данных:
#
# * 2000 строк (записей о сотрудниках)
# * 2 столбца
#
# Пропуски отсутствуют
#
# Типы признаков
# Числовые:
#
# * id — уникальный идентификатор сотрудника (int64)
# * job_satisfaction_rate — уровень удовлетворенности работой (float64, диапазон 0.0-1.0)

# %% [markdown]
# **Вывод**
#
# * данные загружены
# * названия столбцов удовлетворяют единому стандарту
# * типы данных корректны
# * есть пропуски в данных
#
# От пропусков в данных избавимся на этапе предобработки данных

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# **Обработка пропусков**

# %%
train_job_satisfaction.isna().sum()
# Out:
# id                       0
# dept                     6
# level                    4
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# job_satisfaction_rate    0
# dtype: int64

# %%
test_features.isna().sum()
# Out:
# id                       0
# dept                     2
# level                    1
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# dtype: int64

# %%
test_target_job_satisfaction.isna().sum()
# Out:
# id                       0
# job_satisfaction_rate    0
# dtype: int64

# %% [markdown]
# Имеются пропуски в категориальных данных. Избавимся от пропусков в дальнейшем с помощью пайплайна. Каким способом будем заполнять пропуски - решим на этапе исследовательского анализа данных

# %% [markdown]
# **Обработка дубликатов**

# %% [markdown]
# Приведем строковые значения к нижнему регистру

# %%
str_train_job_satisfaction = ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']
str_test_features = ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']

# %%
def lower(df, list_col):
    for elem in list_col:
        df[elem] = df[elem].str.lower()

# %%
lower(train_job_satisfaction, str_train_job_satisfaction)
lower(test_features, str_test_features)

# %% [markdown]
# **Теперь проверим наличие неявных дубликатов в датафреймах**

# %%
for elem in str_train_job_satisfaction:
    print(train_job_satisfaction[elem].value_counts())
    print('\n')
# Out:
# dept
# sales         1512
# technology     866
# purchasing     610
# marketing      550
# hr             456
# Name: count, dtype: int64
#
#
# level
# junior    1894
# middle    1744
# sinior     358
# Name: count, dtype: int64
#
#
# workload
# medium    2066
# low       1200
# high       734
# Name: count, dtype: int64
#
#
# last_year_promo
# no     3880
# yes     120
# Name: count, dtype: int64
#
#
# last_year_violations
# no     3441
# yes     559
# Name: count, dtype: int64

# %% [markdown]
# В train_job_satisfaction неявные дубликаты отсутствуют

# %%
for elem in str_test_features:
    print(test_features[elem].value_counts())
    print('\n')
# Out:
# dept
# sales         763
# technology    455
# marketing     279
# purchasing    273
# hr            227
#                 1
# Name: count, dtype: int64
#
#
# level
# junior    974
# middle    854
# sinior    171
# Name: count, dtype: int64
#
#
# workload
# medium    1043
# low        593
# high       363
#              1
# Name: count, dtype: int64
#
#
# last_year_promo
# no     1937
# yes      63
# Name: count, dtype: int64
#
#
# last_year_violations
# no     1738
# yes     262
# Name: count, dtype: int64

# %% [markdown]
# Неявные дубликаты отсутствуют, однако в столбце **level** уровень 'sinior' переименуем в 'senior'. Также в столбце **workload** имеется 1 пробел, устраним его на этапе обработки пропусков в пайплайне

# %%
train_job_satisfaction['level'].replace('sinior', 'senior', inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9472\2945082487.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_job_satisfaction['level'].replace('sinior', 'senior', inplace=True)

# %%
train_job_satisfaction['level'].value_counts()
# Out:
# level
# junior    1894
# middle    1744
# senior     358
# Name: count, dtype: int64

# %%
test_features['level'].replace('sinior', 'senior', inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9472\122865274.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_features['level'].replace('sinior', 'senior', inplace=True)

# %%
test_features['level'].value_counts()
# Out:
# level
# junior    974
# middle    854
# senior    171
# Name: count, dtype: int64

# %% [markdown]
# **Теперь проверим наличие явных дубликатов в датафреймах**

# %%
train_job_satisfaction.duplicated().sum()
# Out:
# 0

# %%
test_features.duplicated().sum()
# Out:
# 0

# %%
test_target_job_satisfaction.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явные дубликаты отсутствуют

# %% [markdown]
# **Вывод**
#
# 1. Обнаружены пропуски:
#
# * train_job_satisfaction в столбцах **dept** и **level**
# * test_features в столбцах **dept** и **level**
#
# Пропуски будут устранены в пайплайне
#
# 2. Дубликаты отсутствуют
#
# Также в столбце workload имеется 1 пробел, устраним его на этапе обработки пропусков в пайплайне

# %% [markdown]
# ### Исследовательский анализ данных

# %%
# Функция для построения графиков количественного признака
def grafics(df_col, label_x2, label_y2, title):
    # Создание фигуры и осей
    fig, axs = plt.subplots(1, 2, figsize=(12, 5))
    fig.suptitle(title, fontsize=14, y=1.05)  # Общий заголовок
    # Гистограмма
    axs[0].hist(df_col,edgecolor='black', bins=30, alpha=0.7)
    axs[0].set_title('Гистограмма', fontsize=12)
    axs[0].set_xlabel(label_x2, fontsize=10)
    axs[0].set_ylabel(label_y2, fontsize=10)
    axs[0].grid(linestyle='--', alpha=0.5)
    # Диаграмма размаха
    sns.boxplot(
        x=df_col, 
        ax=axs[1], 
        color='lightgreen', 
        width=0.4,
        linewidth=1.5,
        flierprops=dict(
            marker='o', 
            markerfacecolor='red', 
            markersize=6,
            markeredgecolor='black'
        )
    )
    axs[1].set_title('Диаграмма размаха (Boxplot)', fontsize=12)
    axs[1].set_xlabel(label_x2, fontsize=10)
    
    
    plt.tight_layout()
    plt.show()

# %%
def graf(df_col, title):
    category_counts = df_col.value_counts()
    colors = ['#FF9AA2', '#A2E1FF', '#A2FFC7', '#FFB7B2']
    bar_colors = colors[:len(category_counts)]
    
    plt.figure(figsize=(7, 4))
    
    # Создаем график с автоматическим подбором ширины
    bars = plt.bar(category_counts.index, 
                 category_counts.values, 
                 color=bar_colors,
                 edgecolor='black',
                 linewidth=1,
                 alpha=0.8,
                 width=0.6)  # Фиксированная ширина столбцов
    
    # Добавляем подписи значений
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height,
                f'{height}',
                ha='center',  # Центрирование по горизонтали
                va='bottom',  # Выравнивание по основанию
                fontsize=10)
    
    # Настройки графика
    plt.title(title, fontsize=14, pad=20)
    plt.ylabel('Количество', fontsize=12)
    
    # Центрированные подписи без поворота
    plt.xticks(ha='center')  # Ключевое изменение - центрирование подписей
    
    # Убираем лишние линии
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)
    
    # Автоматическая подгонка layout
    plt.tight_layout()
    plt.show()

# %%
def plot_countplot(data, feature, xlabel=None, ylabel=None, title=None):

    plt.figure(figsize=(10, 5))
    ax = sns.countplot(x=feature, data=data)
    
    # Добавляем подписи с процентами
    total = len(data)
    for p in ax.patches:
        percentage = f'{p.get_height()/total:.1%}'
        ax.annotate(percentage, 
                   (p.get_x() + p.get_width()/2., p.get_height()),
                   ha='center', va='center', 
                   xytext=(0, 5), 
                   textcoords='offset points')
    
    # Устанавливаем подписи осей
    plt.xlabel(xlabel if xlabel else feature)
    plt.ylabel(ylabel if ylabel else "Количество")
    
    # Устанавливаем заголовок
    plt.title(title if title else f'Распределение по признаку {feature}')
    
    plt.xticks(rotation=0)
    plt.tight_layout()  # Чтобы подписи не обрезались
    plt.show()

# %% [markdown]
# **Изучим количественные признаки train_job_satisfaction**

# %%
num_col_names = train_job_satisfaction.select_dtypes(include='number').columns.tolist()
num_col_names
# Out:
# ['id',
#  'employment_years',
#  'supervisor_evaluation',
#  'salary',
#  'job_satisfaction_rate']

# %%
plot_countplot(
    data=train_job_satisfaction,
    feature='employment_years',
    xlabel="Стаж работы (лет)",
    ylabel="Число сотрудников",
    title="Распределение сотрудников по стажу"
)

# %%
plot_countplot(
    data=train_job_satisfaction,
    feature='supervisor_evaluation',
    xlabel="Оценка руководителя",
    ylabel="Количество сотрудников",
    title="Распределение оценок руководителей"
)

# %% [markdown]
# Вывод:
#
# * Большинство сотрудников работают в компании относительно недолго.
# * Распределение скошено вправо: много новых сотрудников, и с увеличением стажа — всё меньше людей остаются.
# * Диаграмма хорошо иллюстрирует, что типичный стаж — около 3 лет, а основная масса — от 1 до 6 лет.

# %% [markdown]
# Общий вывод:
#
# * Оценки руководителей в целом положительные: основная масса сотрудников получает оценки 3 или 4.
# * Медианное значение и распределение симметричны в сторону хорошей работы.
# * Оценки ниже 2 и выше 4 встречаются редко, что может указывать на стандартизированный подход к оценке сотрудников или на их устойчиво высокий уровень.

# %%
grafics(train_job_satisfaction['salary'], 'Ежемесячная зарплата сотрудника', 'Количество', 
       'Распределение ежемесячной зарплаты')

# %% [markdown]
# Общий вывод:
#
# * Большинство сотрудников получают зарплату 20–40 тыс.
# * Зарплатное распределение скошено вправо, что типично для компаний с немногими высокооплачиваемыми позициями.
# * Высокие зарплаты — редкость и являются выбросами, что говорит о большом неравенстве в оплате труда.
# * Такой профиль может указывать на пирамидальную структуру компании, где основная масса сотрудников — это исполнители со средней оплатой, а небольшое количество — топ-менеджмент с высокой.

# %%
 grafics(train_job_satisfaction['job_satisfaction_rate'], 'Уровень удовлетворённости сотрудника работой в компании', 'Количество', 
       'Распределение уровня удовлетворённости сотрудника работой в компании (Целевой признак)')

# %% [markdown]
# Общий вывод:
#
# * В среднем уровень удовлетворенности сотрудников компанией 0.4-0.8
# * Пики приходятся на уровни примерно 0.4 и 0.7

# %% [markdown]
# **Изучим категориальные признаки train_job_satisfaction**

# %%
cat_col_names = train_job_satisfaction.select_dtypes(exclude='number').columns.tolist()
cat_col_names
# Out:
# ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']

# %%
graf(train_job_satisfaction['dept'], 'Отдел, в котором работает сотрудник')

# %% [markdown]
# Общий вывод:
#
#
# * Большая часть сотрудников компании работает в отделе продаж
# * Технологический отдел занимает 2 место, что может говтоить о важности технических специалистов для бизнеса

# %%
graf(train_job_satisfaction['level'], 'Уровень занимаемой должности')

# %% [markdown]
# Общий вывод:
#
# * Наибольшее количество сотрудников находится на уровне Junior (1894), что может свидетельствовать о фокусе на молодых специалистах, стажёрах или начальном уровне квалификации.
#
# * Число Middle специалистов тоже высоко (1744), что говорит о хорошем уровне профессионалов с опытом.
#
# * Senior специалистов значительно меньше (358), что типично для большинства организаций, так как таких специалистов меньше на рынке, они дороже и реже требуются в большом количестве

# %%
graf(train_job_satisfaction['workload'], 'Уровень загруженности сотрудника')

# %% [markdown]
# Общий вывод:
#
# * Medium (2066) – большинство сотрудников работают при умеренной нагрузке, что говорит о хорошем балансе задач и ресурсов.
#
# * Low (1200) – значительная часть сотрудников недозагружена, возможно, есть свободные ресурсы, которые можно использовать эффективнее.
#
# * High (734) – часть команды работает на пределе, что может привести к выгоранию; стоит оценить необходимость перераспределения задач или найма.

# %%
graf(train_job_satisfaction['last_year_promo'], 'Было ли повышение за последний год')

# %% [markdown]
# Вывод:
# Лишь 120 сотрудников из 4000 получили повышение за последний год — это всего 3%.
#
# Это может указывать на:
#
# * ограниченные возможности карьерного роста
#
# * высокие требования к повышению
#
# * или редкость пересмотра позиций

# %%
graf(train_job_satisfaction['last_year_violations'], 'Нарушал ли сотрудник трудовой договор за последний год')

# %% [markdown]
# Вывод:
#
# Около 14% сотрудников (559 из 4000) допускали нарушения условий договора за последний год.
# Это не критическая, но заметная доля, что может говорить о:
#
# * недостаточной дисциплине в части коллектива
#
# * пробелах в управлении или коммуникации требований
#
# * или высоком уровне стресса/нагрузки у части сотрудников

# %% [markdown]
# **Вывод по обработке пропусков в train_job_satisfaction**

# %% [markdown]
# Пропуски в столбцах **debt** и **level** заполним модой

# %% [markdown]
# **Изучим количественные признаки test_features**

# %%
num_col_names = test_features.select_dtypes(include='number').columns.tolist()
num_col_names
# Out:
# ['id', 'employment_years', 'supervisor_evaluation', 'salary']

# %%
plot_countplot(
    data=train_job_satisfaction,
    feature='employment_years',
    xlabel="Стаж работы (лет)",
    ylabel="Число сотрудников",
    title="Распределение сотрудников по стажу"
)

# %% [markdown]
# Распределение похоже на то, которое было в предыдущем датасете
#
# * Большинство сотрудников работают в компании относительно недолго.
# * Распределение скошено вправо: много новых сотрудников, и с увеличением стажа — всё меньше людей остаются.
# * Диаграмма хорошо иллюстрирует, что типичный стаж — около 3 лет, а основная масса — от 1 до 6 лет.

# %%
plot_countplot(
    data=test_features,
    feature='supervisor_evaluation',
    xlabel="Оценка руководителя",
    ylabel="Количество сотрудников",
    title="Распределение оценок руководителей"
)

# %% [markdown]
# Распределение похоже на то, которое было в предыдущем датасете
#
# * Оценки руководителей в целом положительные: основная масса сотрудников получает оценки 3 или 4.
# * Медианное значение и распределение симметричны в сторону хорошей работы.
# * Оценки ниже 2 и выше 4 встречаются редко, что может указывать на стандартизированный подход к оценке сотрудников или на их устойчиво высокий уровень.

# %%
grafics(test_features['salary'], 'Ежемесячная зарплата сотрудника', 'Количество', 
       'Распределение ежемесячной зарплаты')

# %% [markdown]
# Распределение похоже на то, которое было в предыдущем датасете
#
# * Большинство сотрудников получают зарплату 20–40 тыс.
# * Зарплатное распределение скошено вправо, что типично для компаний с немногими высокооплачиваемыми позициями.
# * Высокие зарплаты — редкость и являются выбросами, что говорит о большом неравенстве в оплате труда.
# * Такой профиль может указывать на пирамидальную структуру компании, где основная масса сотрудников — это исполнители со средней оплатой, а небольшое количество — топ-менеджмент с высокой.

# %% [markdown]
# **Изучим категориальные признаки test_features**

# %%
cat_col_names = test_features.select_dtypes(exclude='number').columns.tolist()
cat_col_names
# Out:
# ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']

# %%
graf(test_features['dept'], 'Отдел, в котором работает сотрудник')

# %% [markdown]
# Также, как и в преыддущем датасете, большая часть сотрудников работает в отделе продаж, а 2 место занимают сотрудники технического отдела

# %%
graf(test_features['level'], 'Уровень занимаемой должности')

# %% [markdown]
# Также, как и в предыдущем датасете, большая часть сотрудников уровня junior и middle

# %%
graf(test_features['workload'], 'Уровень загруженности сотрудника')

# %% [markdown]
# Распределение выглядит также, как и в предыдущем датасете

# %%
graf(test_features['last_year_promo'], 'Было ли повышение за последний год')

# %% [markdown]
# Распределение выглядит также, как и в предыдущем датасете

# %%
graf(test_features['last_year_violations'], 'Нарушал ли сотрудник трудовой договор за последний год')

# %% [markdown]
# Распределение выглядит также, как и в предыдущем датасете

# %% [markdown]
# **Вывод по обработке пропусков в test_features**

# %% [markdown]
# Пропуки в столбцах **dept** и **level** заполним модой. Пробел в столбце **workload** заменим также заменим на моду

# %% [markdown]
# **Изучим количественные признаки test_target_job_satisfaction**

# %%
num_col_names = test_target_job_satisfaction.select_dtypes(include='number').columns.tolist()
num_col_names
# Out:
# ['id', 'job_satisfaction_rate']

# %%
grafics(test_target_job_satisfaction['job_satisfaction_rate'], 'Уровень удовлетворённости сотрудника работой в компании', 'Количество', 
       'Распределение уровня удовлетворённости сотрудника работой в компании (Целевой признак)')

# %% [markdown]
# Распределение очень похоже с распределением 1го датасета
#
# * В среднем уровень удовлетроваенности сотрудников компанией 0.4-0.8
# * Пики приходятся на уровни примерно 0.4 и 0.7

# %% [markdown]
# **Вывод**
#
# * Даннее исследованы
# * Пропуски в столбцах **level** и **debt** и проблем в столбце **workload** будут заменены на моду

# %% [markdown]
# ### Подготовка данных

# %% [markdown]
# Перед тем как подготавливать данные для обучения модели, посмотрим на phik матрицу тренировочного датафрейма train_job_satisfaction

# %%
# сделаем столбец 'id' индексом датафрейма train_job_satisfaction
train_job_satisfaction.set_index('id', inplace=True)

# %%
train_job_satisfaction.select_dtypes('number').columns.tolist()
# Out:
# ['employment_years',
#  'supervisor_evaluation',
#  'salary',
#  'job_satisfaction_rate']

# %%
interval_cols = ['salary', 'job_satisfaction_rate']
phik_overview = train_job_satisfaction.phik_matrix(interval_cols=interval_cols)

# %%
plt.figure(figsize=(14,10))
sns.heatmap(phik_overview,  annot=True)
plt.title('Матрица корреляции PHIK', fontsize=14)
plt.show()

# %% [markdown]
# * мультиколлинеарность отсутствует
# * признак **supervisor_evaluation** сильно связан с целевым **job_satisfaction_rate**
# * признак **last_year_violations** умеренно связан с целевым **job_satisfaction_rate**
# * признаки **salary**, **last_year_promo**, **employment_years** слабо связаны с целевым **job_satisfaction_rate**
# * признаки **debt**, **level**, **workload** очень слабо с целевым **job_satisfaction_rate**

# %%
merged_test_data = pd.merge(
    left=test_features,
    right=test_target_job_satisfaction,
    on='id',          # Столбец для объединения
    how='inner'       # Используем только совпадающие id
)

# %%
# сделаем столбец 'id' индексом датафрейма train_job_satisfaction
merged_test_data.set_index('id', inplace=True)

# %%
merged_test_data.select_dtypes('number').columns.tolist()
# Out:
# ['employment_years',
#  'supervisor_evaluation',
#  'salary',
#  'job_satisfaction_rate']

# %%
interval_cols = ['salary', 'job_satisfaction_rate']

# %%
phik_overview = merged_test_data.phik_matrix(interval_cols=interval_cols)

plt.figure(figsize=(14,10))
sns.heatmap(phik_overview,  annot=True)
plt.title('Матрица корреляции PHIK', fontsize=14)
plt.show()

# %%
train_job_satisfaction.duplicated().sum()
# Out:
# 245

# %%
train_job_satisfaction.drop_duplicates(inplace=True)

# %% [markdown]
# Теперь подготовим признаки с помощью пайлайна.
#
# Необходимо выполнить:
#
# * предобработку данных (заполнить пропуски на моду и заменить пробел на моду)
# * кодировать и масштабировать признаки несколькими способами. Категориальные данные будем кодировать через OneHotEncoder и OrdinalEncoder. Количественные признаки будем масшабировать через StandardScaler и MinMaxScaler;

# %%
train_job_satisfaction.head()
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 155278       sales  junior   medium                 2              no
# 653870          hr  junior     high                 2              no
# 184592       sales  junior      low                 1              no
# 171431  technology  junior      low                 4              no
# 693419          hr  junior   medium                 1              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# 155278                   no                      1   24000
# 653870                   no                      5   38400
# 184592                   no                      2   12000
# 171431                   no                      2   18000
# 693419                   no                      3   22800
#
#         job_satisfaction_rate
# id
# 155278                   0.58
# 653870                   0.76
# 184592                   0.11
# 171431                   0.37
# ...

# %% [markdown]
# **Пайплайн для подготовки данных**

# %% [markdown]
# Разобьем признаки на входные и целевой

# %%
X_train = train_job_satisfaction.drop('job_satisfaction_rate', axis=1)
y_train = train_job_satisfaction['job_satisfaction_rate']

# %%
# создаём списки с названиями признаков
ohe_columns = ['dept', 'last_year_promo', 'last_year_violations']
ord_columns = ['level', 'workload']
num_columns = X_train.select_dtypes(include='number').columns.tolist()

# %%
ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
    ]
    )

# %%
# создаём пайплайн для подготовки признаков из списка ord_columns: заполнение пропусков и Ordinal-кодирование
# SimpleImputer + OE
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[
                    ['junior', 'middle', 'senior'],
                    ['low', 'medium', 'high'],
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# %%
# создаём общий пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %% [markdown]
# **Итоговый пайплайн**

# %%
# создаём итоговый пайплайн: подготовка данных и модель
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeRegressor(random_state=42))
])

# %% [markdown]
# ### Обучение моделей

# %% [markdown]
# **Словарь для перебора моделей и гиперпараметров**

# %%
param_grid = [
    # Параметры для DecisionTreeRegressor
    {
        'models': [DecisionTreeRegressor(random_state=42)],
        'models__max_depth': range(2, 20),
        'models__max_features': range(2, 20),
        'models__min_samples_leaf': range(2, 20),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # Параметры для LinearRegression
    {
        'models': [LinearRegression()],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    
    # Параметры для Ridge
    {
        'models': [Ridge(random_state=42)],
        'models__alpha': [0.001, 0.01, 0.1, 1, 10],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    
    # Параметры для Lasso
    {
        'models': [Lasso(random_state=42)],
        'models__alpha': [0.001, 0.01, 0.1, 1, 10],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    
    # Параметры для ElasticNet
    {
        'models': [ElasticNet(random_state=42)],
        'models__alpha': [0.001, 0.01, 0.1, 1, 10],
        'models__l1_ratio': [0.2, 0.5, 0.8],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    {
    'models': [CatBoostRegressor(verbose=0, random_state=42, allow_writing_files=False)],
    'models__iterations': [100, 200, 300, 500, 700, 1000],
    'models__depth': [3, 4, 5, 6, 7, 8, 9, 10],
    'models__learning_rate': [0.001, 0.005, 0.01, 0.05, 0.1, 0.2, 0.3],
    'models__l2_leaf_reg': [0.1, 0.5, 1, 3, 5, 7, 10],
    'models__border_count': [32, 64, 128, 254],
    'models__grow_policy': ['SymmetricTree', 'Depthwise', 'Lossguide'],
    'models__min_data_in_leaf': [1, 3, 5, 7, 10],
    'models__random_strength': [0, 0.1, 0.5, 1, 2],
    'models__bagging_temperature': [0, 0.5, 1, 2],
    'models__leaf_estimation_iterations': [1, 3, 5, 10],
    'models__leaf_estimation_method': ['Newton', 'Gradient'],
    'preprocessor__num': ['passthrough']
    }
]

# %% [markdown]
# **Создадим метрику SMAPE**

# %%
def smape(y_true, y_pred):
    denominator = (np.abs(y_true) + np.abs(y_pred))
    safe_denominator = np.where(denominator == 0, 1e-10, denominator)
    return 100 * np.mean(2 * np.abs(y_pred - y_true) / safe_denominator)

smape_scorer = make_scorer(smape, greater_is_better=False)

# %% [markdown]
# Чтобы сократить время на поиск лучшей модели, используем RandomizedSearchCV

# %%
randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_distributions=param_grid,
    cv=5,
    scoring=smape_scorer, 
    random_state=42,
    n_jobs=-1,
    n_iter=25
)
randomized_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('simpleImputer_ohe',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('ohe',
#                                                                                                 OneHotEncoder(drop='first',
#                                                                                                               handle_unknown='ignore',
# ...

# %%
print('Лучшая модель:\n', randomized_search.best_estimator_)
print('Лучший SMAPE:', randomized_search.best_score_*(-1))
# Out:
# Лучшая модель:
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['dept', 'last_year_promo',
#                                                    'last_year_violations']),
#                                                  ('ord',
# ...

# %%
X_test = merged_test_data.drop(columns=['job_satisfaction_rate'])
y_test1 = merged_test_data['job_satisfaction_rate'].values

y_pred1 = randomized_search.predict(X_test)
print(f'Метрика SMAPE на тестовой выборке: {smape(y_test1, y_pred1):.2f}')
# Out:
# Метрика SMAPE на тестовой выборке: 10.72
# C:\Users\user\anaconda3\envs\practicum\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# Полученная метрика **SMAPE: 13.48** удовлетворяет критерию успеха

# %% [markdown]
# Сравним качество нашей модели с константной моделью DummyRegressor.

# %%
dummy = DummyRegressor(strategy='mean')

# 1. Получаем лучшую модель из RandomizedSearchCV
best_model = randomized_search.best_estimator_
preprocessor = best_model.named_steps['preprocessor']

# 2. Преобразуем данные
X_train_preprocessed = preprocessor.transform(X_train)

# Оценка на тестовых данных
X_test_preprocessed = preprocessor.transform(X_test)

# Dummy модель
dummy.fit(X_train_preprocessed, y_train)
y_pred_dummy = dummy.predict(X_test_preprocessed)
dummy_test_smape = smape(y_test1, y_pred_dummy)

print(f"\nТестовые данные:")
print(f"DummyRegressor SMAPE: {dummy_test_smape:.4f}")
# Out:
# Тестовые данные:
# DummyRegressor SMAPE: 38.2623
# C:\Users\user\anaconda3\envs\practicum\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
#
# Метрика константной модели явно хуже нашей модели

# %% [markdown]
# ### Оформление выводов

# %% [markdown]
# Для выполнения задачи были использованы линейная модель(включая ее разновидности) и модель деревья решений. Лучше моделью оказалась модель деревья решений.

# %% [markdown]
# Параметры лучшей модели:

# %%
model_1 = randomized_search.best_estimator_.named_steps['models']
model_1

# %% [markdown]
# Деревья решений превзошли линейные модели в прогнозировании удовлетворенности сотрудников благодаря ключевым преимуществам:
#
# * Удовлетворенность сотрудников (job_satisfaction_rate) часто зависит от сложных нелинейных взаимодействий признаков       ("Высокая зарплата + гибкий график" дают больший эффект, чем сумма отдельных факторов). Решение дерева автоматически обнаруживает такие взаимодействия через ветвления.
#
# * Линейные модели предполагают линейную связь между признаками и целевой переменной, однако в нашем случае линейной зависимости почти нет

# %% [markdown]
# ## Задача 2: предсказание увольнения сотрудника из компании

# %% [markdown]
# ### Загрузка данных

# %%
# Загрузка датасетов
train_quit = load_dataset('/datasets/train_quit.csv')
test_target_quit = load_dataset('/datasets/test_target_quit.csv')

# %%
display(train_quit.head())
train_quit.info()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ...

# %% [markdown]
# Обзор данных:
#
# * 4000 записей о сотрудниках
# * 10 признаков, включая целевой (quit)
# * Нет пропущенных значений
#
# Типы данных:
#
# * Числовые: id, employment_years, supervisor_evaluation, salary
# * Категориальные: dept, level, workload, last_year_promo, last_year_violations, quit

# %%
display(test_features.head())
test_features.info()
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary
# 0                   no                      5   28800
# 1                   no                      4   30000
# 2                   no                      4   19200
# 3                   no                      4   19200
# 4                   no                      5   40800
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ...

# %%
display(test_target_quit.head())
test_target_quit.info()
# Out:
#        id quit
# 0  999029  yes
# 1  372846   no
# 2  726767   no
# 3  490105   no
# 4  416898  yes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2000 non-null   int64
#  1   quit    2000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB

# %% [markdown]
# Обзор данных:
#
# * 2000 записей о сотрудниках
#
# 2 столбца:
#
# * id - уникальный идентификатор (int64)
# * quit - факт увольнения (object: "yes"/"no")
#
# Нет пропущенных значений

# %% [markdown]
# **Вывод**
#
# * Тип данных везде корректен
# * Есть пропуски в датафрейме test_features в столбцах **dept** и **level**

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# **Обработка дубликатов**

# %% [markdown]
# Приведем строковые значения к нижнему регистру

# %%
str_train_quit = ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']
str_test_target_quit = ['quit']

# %%
def lower(df, list_col):
    for elem in list_col:
        df[elem] = df[elem].str.lower()

# %%
lower(train_quit, str_train_quit)
lower(test_target_quit, str_test_target_quit)

# %% [markdown]
# **Теперь проверим наличие неявных дубликатов в датафреймах**

# %% [markdown]
# **В датафрейме test_features проверка на дубликаты проводилась в пункте 1.2**

# %%
for elem in str_train_quit:
    print(train_quit[elem].value_counts())
    print('\n')
# Out:
# dept
# sales         1438
# technology     928
# purchasing     588
# marketing      582
# hr             464
# Name: count, dtype: int64
#
#
# level
# junior    1949
# middle    1694
# sinior     357
# Name: count, dtype: int64
#
#
# workload
# medium    2118
# low       1208
# high       674
# Name: count, dtype: int64
#
#
# last_year_promo
# no     3887
# yes     113
# Name: count, dtype: int64
#
#
# last_year_violations
# no     3455
# yes     545
# Name: count, dtype: int64

# %% [markdown]
# Неявные дубликаты отсутствуют, однако в столбце **level** уровень 'sinior' переименуем в 'senior'.

# %%
train_quit['level'].replace('sinior', 'senior', inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9472\3101193052.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_quit['level'].replace('sinior', 'senior', inplace=True)

# %%
train_quit['level'].value_counts()
# Out:
# level
# junior    1949
# middle    1694
# senior     357
# Name: count, dtype: int64

# %%
for elem in str_test_target_quit:
    print(test_target_quit[elem].value_counts())
    print('\n')
# Out:
# quit
# no     1436
# yes     564
# Name: count, dtype: int64

# %% [markdown]
# Неявные дубликаты отсутствуют

# %% [markdown]
# **Теперь проверим наличие явных дубликатов в датафреймах**

# %%
train_quit.duplicated().sum()
# Out:
# 0

# %%
test_target_quit.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явные дубликаты отсутствуют

# %% [markdown]
# **Вывод**
#
# 1. Обнаружены пропуски:
#
# * test_features в столбцах **dept** и **level**
#
# Пропуски будут устранены в пайплайне

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# **Исследуем признаки датафреймов train_quit и test_target_quit на наличие выбросов**

# %% [markdown]
# Изучим количественные признаки train_quit

# %%
num_col_names = train_quit.select_dtypes(include='number').columns.tolist()
num_col_names
# Out:
# ['id', 'employment_years', 'supervisor_evaluation', 'salary']

# %%
plot_countplot(
    data=train_quit,
    feature='employment_years',       
    xlabel="Стаж работы (лет)",
    ylabel="Количество сотрудников",
    title="Распределение сотрудников по стажу работы",                
)

# %%
plot_countplot(
    data=train_quit,
    feature='supervisor_evaluation',
    xlabel='Оценка руководителя (1-5 баллов)',
    ylabel='Количество сотрудников',
    title='Распределение оценок качества работы сотрудников',
)

# %%
grafics(train_quit['salary'], 'Ежемесячная зарплата сотрудника', 'Количество', 
       'Распределение ежемесячной зарплаты')

# %% [markdown]
# Все распределения похожи на распределения из пункта 1.3

# %% [markdown]
# Изучим категориальные признаки train_quit

# %%
cat_col_names = train_quit.select_dtypes(exclude='number').columns.tolist()
cat_col_names
# Out:
# ['dept',
#  'level',
#  'workload',
#  'last_year_promo',
#  'last_year_violations',
#  'quit']

# %%
graf(train_quit['dept'], 'Отдел, в котором работает сотрудник')

# %%
graf(train_quit['level'], 'Уровень занимаемой должности')

# %%
graf(train_quit['workload'], 'Уровень загруженности сотрудника')

# %%
graf(train_quit['last_year_promo'], 'Было ли повышение за последний год')

# %%
graf(train_quit['last_year_violations'], 'Нарушал ли сотрудник трудовой договор за последний год')

# %% [markdown]
# **Общая статистика**

# %%
graf(train_quit['quit'], 'Количество уволившихся (yes) и количество оставшихся (no) человек')

# %%
train_quit['quit'].value_counts(normalize=True)
# Out:
# quit
# no     0.718
# yes    0.282
# Name: proportion, dtype: float64

# %%
quit_counts = train_quit["quit"].value_counts()
labels = ['Остался (0)', 'Уволился (1)']
colors = ['#66b3ff', '#ff9999']

# Круговая диаграмма с процентами на секторах
plt.figure(figsize=(8, 6))
patches, texts, autotexts = plt.pie(
    quit_counts,
    labels=labels,
    colors=colors,
    autopct='%1.1f%%',  # Проценты прямо на секторах
    startangle=90,
    pctdistance=0.8,    # Радиус расположения процентов
    wedgeprops={'edgecolor': 'white', 'linewidth': 1},
    textprops={'fontsize': 12}
)

# Увеличиваем шрифт процентов
for autotext in autotexts:
    autotext.set_color('black')
    autotext.set_fontsize(12)

plt.title("Распределение увольнений в компании", fontsize=14, pad=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# Примерно 28% человек уволились, а 72% остались

# %%
train_quit.groupby('quit')['salary'].mean()
# Out:
# quit
# no     37702.228412
# yes    23885.106383
# Name: salary, dtype: float64

# %%
salary_means = train_quit.groupby('quit')['salary'].mean().reset_index()

# Создаём столбчатую диаграмму
plt.figure(figsize=(6, 5))
sns.barplot(data=salary_means, x='quit', y='salary', palette=['#ff6961', '#77dd77'])

plt.title('Средняя зарплата по статусу увольнения', fontsize=14)
plt.xlabel('Уволился (quit)', fontsize=12)
plt.ylabel('Средняя зарплата', fontsize=12)
plt.xticks([0, 1], ['Остался', 'Уволился'])
plt.grid(axis='y', linestyle='--', alpha=0.6)

for index, row in salary_means.iterrows():
    plt.text(index, row['salary'] + 0.5, f"{row['salary']:.0f}", 
             ha='center', va='bottom', fontsize=11)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9472\3893703972.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=salary_means, x='quit', y='salary', palette=['#ff6961', '#77dd77'])

# %% [markdown]
# **Уволился**
#
# * медианная зарплата 22800р, средняя зарплата 23885р
#
# **Остался**
#
# * медианная зарплата 34800р, средняя зарплата 37702р

# %% [markdown]
# #### **Портрет уволившегося сотрудника**

# %%
def plot_quit_distribution(data, column_name, color='#ff6b6b', 
                         xlabel=None, ylabel=None, title=None):
    # Получаем данные только по уволившимся
    quit_data = data[data['quit'] == 'yes']
    
    # Считаем процентное распределение
    dist = quit_data[column_name].value_counts(normalize=True) * 100
    dist = dist.sort_values(ascending=False)
    
    # Создаем фигуру
    plt.figure(figsize=(10, 6))
    
    # Рисуем столбцы
    bars = plt.bar(dist.index, dist.values, color=color)
    
    # Добавляем подписи значений
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, 
                height + 0.5, 
                f'{height:.1f}%', 
                ha='center',
                va='bottom')
    
    # Устанавливаем подписи осей
    plt.xlabel(xlabel if xlabel else column_name, fontsize=12, labelpad=10)
    plt.ylabel(ylabel if ylabel else 'Доля от всех увольнений (%)', fontsize=12, labelpad=10)
    
    # Устанавливаем заголовок
    if title is None:
        title = f'Распределение увольнений по "{column_name}"'
    plt.title(title, fontsize=14, pad=20)
    
    # Дополнительные настройки
    plt.xticks(rotation=0, ha='center')
    plt.ylim(0, dist.max() * 1.15)
    plt.grid(axis='y', linestyle='--', alpha=0.3)
    plt.tight_layout()
    plt.show()

# %%
salary_means = train_quit.groupby('quit')['salary'].median().reset_index()

# Создаём столбчатую диаграмму
plt.figure(figsize=(6, 5))
sns.barplot(data=salary_means, x='quit', y='salary', palette=['#ff6961', '#77dd77'])

plt.title('Медианная зарплата по статусу увольнения', fontsize=14)
plt.xlabel('Уволился (quit)', fontsize=12)
plt.ylabel('Средняя зарплата', fontsize=12)
plt.xticks([0, 1], ['Остался', 'Уволился'])
plt.grid(axis='y', linestyle='--', alpha=0.6)

for index, row in salary_means.iterrows():
    plt.text(index, row['salary'] + 0.5, f"{row['salary']:.0f}", 
             ha='center', va='bottom', fontsize=11)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9472\2421712861.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=salary_means, x='quit', y='salary', palette=['#ff6961', '#77dd77'])

# %%
plot_quit_distribution(
    data=train_quit,
    column_name='dept',
    color='#1f77b4',
    xlabel='Отдел',
    ylabel='Доля уволившихся (%)',
    title='Распределение увольнений по отделам'
)

# %%
plot_quit_distribution(
    data=train_quit,
    column_name='workload',
    color='#4e79a7',
    xlabel='Уровень рабочей нагрузки',
    ylabel='Процент уволившихся',
    title='Зависимость увольнений от рабочей нагрузки'
)

# %%
plot_quit_distribution(
    data=train_quit,
    column_name='level',
    color='#ff7f0e',
    xlabel='Уровень позиции',
    ylabel='Доля уволившихся (%)',
    title='Увольнения по уровням должностей'
)

# %%
plot_quit_distribution(
    data=train_quit,
    column_name='last_year_promo',
    color='#d62728',
    xlabel='Получал повышение',
    ylabel='Доля уволившихся (%)',
    title='Влияние повышения на увольнения'
)

# %%
plot_quit_distribution(
    data=train_quit,
    column_name='last_year_violations',
    color='#9467bd',
    xlabel='Наличие нарушений',
    ylabel='Доля уволившихся (%)',
    title='Связь нарушений с увольнениями'
)

# %%
plot_quit_distribution(
    data=train_quit,
    column_name='supervisor_evaluation',
    color='#e377c2',
    xlabel='Оценка руководителя',
    ylabel='Доля уволившихся (%)',
    title='Влияние оценки руководителя на увольнения'
)

# %%
plot_quit_distribution(
    data=train_quit,
    column_name='employment_years',
    color='#8c564b',
    xlabel='Стаж работы (лет)',
    ylabel='Доля уволившихся (%)',
    title='Увольнения по стажу работы'
)

# %% [markdown]
# На основе графиков можно сделать следующий вывод о портрете уволившегося сотрудника:
#
# * Скорее всего, это сотрудник, который имеет **слабый** или **средний** уровень занятости
# * Наиболее вероятно, что это сотрудник из **отдела по продажам** или **технического отдела**, наименее вероятно, что это сотрудник из отдела **HR**
# * Скорее всего это сотрудник с зарплатой **менее 25000р**
# * Наиболее вероятно, что это сотрудник уровня **junior**
# * Почти точно это сотрудник, который **не получил повышение**
# * Наиболее вероятно, что этот мотрудник получил **оценку 3** у руководителя
# * Скорее всего этот сотрудник **не делал нарушений**
# * С большей вероятностью стаж этого сотрудника 1-2 года

# %% [markdown]
# **Проверка уровня связи удовлетворенности компанией и увольнения сотрудника**

# %%
test_data = pd.merge(test_target_job_satisfaction, test_target_quit, on='id')
test_data
# Out:
#           id  job_satisfaction_rate quit
# 0     130604                   0.74   no
# 1     825977                   0.75   no
# 2     418490                   0.60  yes
# 3     555320                   0.72   no
# 4     826430                   0.08  yes
# ...      ...                    ...  ...
# 1995  405257                   0.28   no
# 1996  370925                   0.21  yes
# 1997  857722                   0.39   no
# 1998  303402                   0.26  yes
# 1999  648995                   0.62   no
#
# [2000 rows x 3 columns]

# %%
test_data_yes = test_data[test_data['quit'] == 'yes']
test_data_no = test_data[test_data['quit'] == 'no']
test_data_yes
# Out:
#           id  job_satisfaction_rate quit
# 2     418490                   0.60  yes
# 4     826430                   0.08  yes
# 20    508688                   0.58  yes
# 29    343440                   0.35  yes
# 30    622918                   0.77  yes
# ...      ...                    ...  ...
# 1982  695964                   0.65  yes
# 1983  503574                   0.12  yes
# 1992  393147                   0.56  yes
# 1996  370925                   0.21  yes
# 1998  303402                   0.26  yes
#
# [564 rows x 3 columns]

# %%
 grafics(test_data_yes['job_satisfaction_rate'], 'Уровень удовлетворённости сотрудника работой в компании', 'Количество', 
       'Распределение уровня удовлетворённости УВОЛИВШЕГОСЯ сотрудника работой в компании (Целевой признак)')

# %%
 grafics(test_data_no['job_satisfaction_rate'], 'Уровень удовлетворённости сотрудника работой в компании', 'Количество', 
       'Распределение уровня удовлетворённости НЕ УВОЛИВШЕГОСЯ сотрудника работой в компании (Целевой признак)')

# %% [markdown]
# Из графиков прекрасно видно, что:
#
# * У уволившихся сотрудников в среднем уровень удовлетворенности меньше (пик смещен влево), чем у сотрудников, оставшихся работать в компании (пик смещен вправо)

# %% [markdown]
#  Аналитики утверждают, что уровень удовлетворённости сотрудника работой в компании влияет на то, уволится ли сотрудник.
#  Проверим это утверждение с помощью ztest.
#
#  Сформулируем гипотезы:
#
#  **Нулевая гипотеза:** Доля увольнений в группе с низкой удовлетворённостью не больше, чем в группе с высокой
#
#  **Альтернативная гипотеза:** Доля увольнений в группе с низкой удовлетворённостью больше

# %%
data = test_data

# %%
# Выборка для сотрудников с высокой удовлетворённостью (верхний квартиль)
high_satisfaction = data[data['job_satisfaction_rate'] >= data['job_satisfaction_rate'].quantile(0.75)]['quit']

# Выборка для сотрудников с низкой удовлетворённостью (нижний квартиль)
low_satisfaction = data[data['job_satisfaction_rate'] <= data['job_satisfaction_rate'].quantile(0.25)]['quit']
# Данные: количество увольнений и размеры групп
count_low = (low_satisfaction == 'yes').sum()  
total_low = len(low_satisfaction)          
count_high = (high_satisfaction == 'yes').sum()
total_high = len(high_satisfaction)

# Односторонний z-тест
z_stat, p_value = proportions_ztest(
    count=[count_low, count_high],
    nobs=[total_low, total_high],
    alternative='larger')

alpha = 0.05
    
print(f'p-значение: {p_value}')

if p_value < alpha:
    print('Отвергаем H₀: доля увольнений в группе с низкой удовлетворённостью значимо выше.')
else:
    print('Не отвергаем H₀: нет доказательств, что низкая удовлетворённость увеличивает увольнения.')
# Out:
# p-значение: 1.7599649475275157e-75
# Отвергаем H₀: доля увольнений в группе с низкой удовлетворённостью значимо выше.

# %% [markdown]
# Статистический тест подтвердил утверждение аналитиков

# %% [markdown]
# ### Добавление нового входного признака

# %% [markdown]
# С помощью лучшей модели, полученной на этапе 1.5, предскажем значения столбца **predicted_job_satisfaction** для датафрейма **train_quit**

# %%
train_quit.head(1)
# Out:
#        id   dept   level workload  employment_years last_year_promo  \
# 0  723290  sales  middle     high                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      4   54000   no

# %%
X_for_prediction = train_quit.drop(columns='id')

# %%
X_for_prediction.head(1)
# Out:
#     dept   level workload  employment_years last_year_promo  \
# 0  sales  middle     high                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      4   54000   no

# %%
predicted_job_satisfaction = randomized_search.best_estimator_.predict(X_for_prediction)

# Добавляем предсказания к исходному датафрейму
train_quit['predicted_job_satisfaction'] = predicted_job_satisfaction

# Теперь в train_quit есть новый признак predicted_job_satisfaction
print(train_quit.head())
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit  \
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no
#
#    predicted_job_satisfaction
# 0                    0.670531
# 1                    0.839680
# 2                    0.365546
# 3                    0.336292
# ...

# %% [markdown]
# Новый столбец добавлен, теперь добавим столбец к тестовым входным данным

# %%
X_for_prediction = test_features.drop(columns='id')
X_for_prediction.head(1)
# Out:
#         dept   level workload  employment_years last_year_promo  \
# 0  marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary
# 0                   no                      5   28800

# %%
predicted_job_satisfaction = randomized_search.best_estimator_.predict(X_for_prediction)

# Добавляем предсказания к исходному датафрейму
test_features['predicted_job_satisfaction'] = predicted_job_satisfaction

# Теперь в train_quit есть новый признак predicted_job_satisfaction
print(test_features.head())
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary  \
# 0                   no                      5   28800
# 1                   no                      4   30000
# 2                   no                      4   19200
# 3                   no                      4   19200
# 4                   no                      5   40800
#
#    predicted_job_satisfaction
# 0                    0.839048
# 1                    0.654039
# 2                    0.663557
# 3                    0.659724
# 4                    0.815913
# ...

# %% [markdown]
# ### Подготовка данных

# %% [markdown]
# Исследуем признаки тренировочного датафрейма **train_quit**

# %%
# сделаем столбец 'id' индексом датафрейма train_quit
train_quit.set_index('id', inplace=True)

# %%
interval_cols = train_quit.select_dtypes('number').columns.tolist()
interval_cols
# Out:
# ['employment_years',
#  'supervisor_evaluation',
#  'salary',
#  'predicted_job_satisfaction']

# %%
interval_cols = ['salary', 'predicted_job_satisfaction']
phik_overview = train_quit.phik_matrix(interval_cols=interval_cols)

plt.figure(figsize=(14,10))
sns.heatmap(phik_overview,  annot=True)
plt.title('Матрица корреляции PHIK', fontsize=14)
plt.show()

# %% [markdown]
# * мультиколлинеарность отсутствует
# * признаки **employmet_years**, **salary**, **pradicted_job_satusfaction** умеренно связаны с целевым **quit**
# * признаки **level**, **supervisor_evaluation**, **last_year_promo**, **last_year_violations** слабо связаны с целевым **quit**
# * признак **debt** не связан с целевым **quit**, возможно, его лучше не учитывать при обучении, будем опираться на метрики

# %% [markdown]
# Теперь посмотрим на матрицу корреляций тестовой выборки. Для начала обьединим тестовые входные признаки и тестовый целевой признак в одну таблицу

# %%
merged_test_data = pd.merge(
    left=test_features,
    right=test_target_quit,
    on='id',          # Столбец для объединения
    how='inner'       # Используем только совпадающие id
)

# %%
merged_test_data.set_index('id', inplace=True)

# %%
merged_test_data.select_dtypes('number').columns.tolist()
# Out:
# ['employment_years',
#  'supervisor_evaluation',
#  'salary',
#  'predicted_job_satisfaction']

# %%
interval_cols = ['salary', 'predicted_job_satisfaction']
phik_overview = merged_test_data.phik_matrix(interval_cols=interval_cols)

plt.figure(figsize=(14,10))
sns.heatmap(phik_overview,  annot=True)
plt.title('Матрица корреляции PHIK', fontsize=14)
plt.show()

# %% [markdown]
# Входные признаки имеют похожую связь с целевым признаком.
#
# Для обучения модели будем использовать все входные признаки

# %% [markdown]
# Теперь подготовим признаки с помощью пайлайна

# %% [markdown]
# **Пайплайн для подготовки данных**

# %% [markdown]
# Разобьем признаки на входные и целевой

# %%
X_train = train_quit.drop('quit', axis=1)
y_train = train_quit['quit']

# %%
X_train.head()
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 723290       sales  middle     high                 2              no
# 814010       sales  junior   medium                 2              no
# 155091  purchasing  middle   medium                 5              no
# 257132       sales  junior   medium                 2              no
# 910140   marketing  junior   medium                 2              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# 723290                   no                      4   54000
# 814010                   no                      4   27600
# 155091                   no                      1   37200
# 257132                  yes                      3   24000
# 910140                   no                      5   25200
#
#         predicted_job_satisfaction
# id
# 723290                    0.670531
# 814010                    0.839680
# 155091                    0.365546
# ...

# %%
y_train.head()
# Out:
# id
# 723290     no
# 814010     no
# 155091     no
# 257132    yes
# 910140     no
# Name: quit, dtype: object

# %%
y_test = merged_test_data['quit']
y_test.head()
# Out:
# id
# 485046    no
# 686555    no
# 467458    no
# 418655    no
# 789145    no
# Name: quit, dtype: object

# %%
# Создаем и настраиваем LabelEncoder
le = LabelEncoder()
le.classes_ = np.array(['no', 'yes'])  # Фиксируем порядок: no=0, yes=1
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.transform(y_test)

print("Соответствие классов:")
print(f"'no' → {le.transform(['no'])[0]}, 'yes' → {le.transform(['yes'])[0]}")
# Out:
# Соответствие классов:
# 'no' → 0, 'yes' → 1

# %%
y_train_encoded
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
# создаём списки с названиями признаков
ohe_columns = ['dept', 'last_year_promo', 'last_year_violations']
ord_columns = ['level', 'workload']
num_columns = X_train.select_dtypes(include='number').columns.tolist()

# %%
ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
    ]
    )

# %%
# создаём пайплайн для подготовки признаков из списка ord_columns: заполнение пропусков и Ordinal-кодирование
# SimpleImputer + OE
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[
                    ['junior', 'middle', 'senior'],
                    ['low', 'medium', 'high'],
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# %%
# создаём общий пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %% [markdown]
# **Итоговый пайплайн**

# %%
# создаём итоговый пайплайн: подготовка данных и модель
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=42))
])

# %% [markdown]
# ### Обучение модели

# %% [markdown]
# **Словарь для перебора моделей и гиперпараметров**

# %%
param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=42)],
        'models__max_depth': range(2,10),
        'models__max_features': range(2,10),
        'models__min_samples_leaf': range(2,10),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2,10),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    # 3. LogisticRegression 
    {
        'models': [LogisticRegression(random_state=42, solver='liblinear')],
        'models__penalty': ['l1', 'l2'],
        'models__C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
        'models__class_weight': [None, 'balanced'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    # словарь для модели SVC()
    {
        'models': [SVC(random_state=42, probability=True)],
        'models__C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
        'models__kernel': ['linear', 'rbf', 'poly', 'sigmoid'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  

    },
]

# %% [markdown]
# Чтобы сократить время на поиск лучшей модели, используем RandomizedSearchCV

# %%
randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_distributions=param_grid,
    cv=5,
    scoring='roc_auc', 
    random_state=42,
    n_jobs=-1,
    n_iter=5
)
randomized_search.fit(X_train, y_train_encoded)

print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print ('Метрика лучшей модели на кросс валидации:', randomized_search.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['dept', 'last_year_promo',
#                                                    'last_year_violations']),
#                                                  ('ord',
# ...

# %%
model_2 = randomized_search.best_estimator_.named_steps['models']
model_2
# Out:
# DecisionTreeClassifier(max_depth=7, max_features=8, min_samples_leaf=9,
#                        random_state=42)

# %% [markdown]
# Объединим тестовые датафреймы **test_features** и **test_target_quit** в один датафрейм, затем снова поделим на входные и целевой признаки, чтобы порядок строк не был перемешен

# %%
merged_test_data = pd.merge(
    left=test_features,
    right=test_target_quit,
    on='id',          # Столбец для объединения
    how='inner'       # Используем только совпадающие id
)

# %%
X_test = merged_test_data.drop(columns=['id', 'quit'])

y_test_pred = randomized_search.predict_proba(X_test)[:,1]
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test_encoded, y_test_pred)}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.9229013562101188
# C:\Users\user\anaconda3\envs\practicum\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# ### Выводы

# %% [markdown]
# DecisionTreeClassifier показал лучший результат, потому что:
#
# * Хорошо работает с нелинейными зависимостями в данных (логистическая регрессия и линейный SVС менее гибкие).
#
# Дерево решений лучше адаптируется к сложным взаимосвязям в данных без жестких предположений о их природе.

# %% [markdown]
#  Сравним качество нашей модели с константной моделью DummyClassifier.

# %%
dummy_clf = DummyClassifier(strategy='stratified')

# 1. Получаем лучшую модель из RandomizedSearchCV
best_model = randomized_search.best_estimator_
preprocessor = best_model.named_steps['preprocessor']

# 2. Преобразуем данные
X_train_preprocessed = preprocessor.transform(X_train)

# Оценка на тестовых данных
X_test_preprocessed = preprocessor.transform(X_test)

# Dummy модель
dummy_clf.fit(X_train_preprocessed, y_train)
y_pred_dummy = dummy_clf.predict_proba(X_test_preprocessed)[:,1]
dummy_test_smape = roc_auc_score(y_test, y_pred_dummy)

print(f"\nТестовые данные:")
print(f"DummyRegressor SMAPE: {dummy_test_smape:.4f}")
# Out:
# Тестовые данные:
# DummyRegressor SMAPE: 0.4836
# C:\Users\user\anaconda3\envs\practicum\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# Метрика константной модели явно хуже нашей модели

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# **Описание задачи**

# %% [markdown]
# Перед нами стояло 2 задачи:
#
# **Задача 1:** предсказание уровня удовлетворённости сотрудника
#
# **Задача 2:** предсказание увольнения сотрудника из компании

# %% [markdown]
# **Описание этапов работы**

# %% [markdown]
# **Этап 1.1 Загрузка данных**
#
# На данном этапе были успешно загружены три датафрейма: ***train_job_satisfaction***, ***test_features***, ***test_target_job_satisfaction*** для решение задачи 1.
#
# Были сделаны следующие выводы:
#
# * данные загружены
# * названия столбцов удовлетворяют единому стандарту
# * типы данных корректны
# * есть пропуски в данных
#
# **Этап 1.2 Предобработка данных**
#
# На данном этапе были исследованы пропуски в данных, явные и неявные дубликаты.
#
# Были сделаны следующие выводы:
#
# Обнаружены пропуски:
# * train_job_satisfaction в столбцах dept и level
# * test_features в столбцах dept и level
#
# Пропуски будут устранены в пайплайне
# * Дубликаты отсутствуют
#
# Также в столбце workload имеется 1 пробел, устраним его на этапе обработки пропусков в пайплайне. Помимо этого, в столбце ***level*** уровень 'sinior' был переименован в 'senior'
#
# **Этап 1.3 Исследовательский анализ данных**
#
# На данном этапе были исследованы все признаки трех датафреймов  ***train_job_satisfaction***, ***test_features***, ***test_target_job_satisfaction***
#
# Были сделаны следующие выводы:
#
# ***Длительность работы в компании***
#
# * Большинство сотрудников работают в компании относительно недолго.
# * Распределение скошено вправо: много новых сотрудников, и с увеличением стажа — всё меньше людей остаются.
# * Диаграмма хорошо иллюстрирует, что типичный стаж — около 3 лет, а основная масса — от 1 до 6 лет.
#
# ***Оценки руководителей***
#
# * Оценки руководителей в целом положительные: основная масса сотрудников получает оценки 3 или 4.
# * Медианное значение и распределение симметричны в сторону хорошей работы.
# * Оценки ниже 2 и выше 4 встречаются редко, что может указывать на стандартизированный подход к оценке сотрудников или на их устойчиво высокий уровень.
#
# ***Зарплата сотрудников***
#
# * Большинство сотрудников получают зарплату 20–40 тыс.
# * Зарплатное распределение скошено вправо, что типично для компаний с немногими высокооплачиваемыми позициями.
# * Высокие зарплаты — редкость и являются выбросами, что говорит о большом неравенстве в оплате труда.
# * Такой профиль может указывать на пирамидальную структуру компании, где основная масса сотрудников — это исполнители со средней оплатой, а небольшое количество — топ-менеджмент с высокой.
#
# ***Уровень удовлетворенности сотрудников***
#
# * В среднем уровень удовлетворенности сотрудников компанией 0.4-0.8
# * Пики приходятся на уровни примерно 0.4 и 0.7
#
# ***Самые популярные отделы компании***
#
# * Большая часть сотрудников компании работает в отделе продаж
# * Технологический отдел занимает 2 место, что может говтоить о важности технических специалистов для бизнеса
#
# ***Уровень сотрудников***
#
# * Наибольшее количество сотрудников находится на уровне Junior (1894), что может свидетельствовать о фокусе на молодых специалистах, стажёрах или начальном уровне квалификации.
# * Число Middle специалистов тоже высоко (1744), что говорит о хорошем уровне профессионалов с опытом.
# * Senior специалистов значительно меньше (358), что типично для большинства организаций, так как таких специалистов меньше на рынке, они дороже и реже требуются в большом количестве
#
# ***Уровень загруженности сотрудников***
#
# * Medium (2066) – большинство сотрудников работают при умеренной нагрузке, что говорит о хорошем балансе задач и ресурсов.
# * Low (1200) – значительная часть сотрудников недозагружена, возможно, есть свободные ресурсы, которые можно использовать эффективнее.
# * High (734) – часть команды работает на пределе, что может привести к выгоранию; стоит оценить необходимость перераспределения задач или найма.
#
# ***Повышение сотрудников***
#
# Лишь 120 сотрудников из 4000 получили повышение за последний год — это всего 3%.
#
# Это может указывать на:
# * ограниченные возможности карьерного роста
# * высокие требования к повышению
# * или редкость пересмотра позиций
#
# ***Нарушения сотрудников***
#
# Около 14% сотрудников (559 из 4000) допускали нарушения условий договора за последний год.
# Это не критическая, но заметная доля, что может говорить о:
# * недостаточной дисциплине в части коллектива
# * пробелах в управлении или коммуникации требований
# * или высоком уровне стресса/нагрузки у части сотрудников
#
# **Этап 1.4 Подготовка данных**
#
# Вначале, с помощью phik матрицы были исследованы взаимосвязи между признаками. Были сделаны следующие выводы:
#
# * мультиколлинеарность отсутствует
# * признак ***supervisor_evaluation*** сильно связан с целевым ***job_satisfaction_rate***
# * признак ***last_year_violations*** умеренно связан с целевым ***job_satisfaction_rate***
# * признаки ***salary***, ***last_year_promo***, ***employment_years*** слабо связаны с целевым **job_satisfaction_rate**
# * признаки ***debt***, ***level***, ***workload*** очень слабо с целевым ***job_satisfaction_rate***
#
# Затем, с помощью пайплайна была выполнена подготовка данных. Были сделаны следующие шаги:
#
# * предобработку данных (заполнить пропуски на моду и заменить пробел на моду)
# * кодировать и масштабировать признаки несколькими способами. Категориальные данные будем кодировать через OneHotEncoder и OrdinalEncoder. Количественные признаки будем масшабировать через StandardScaler и MinMaxScaler;
#
# **Этап 1.5 Обучение модели**
#
# Первым делом была создана метрика ***smape*** (англ. symmetric mean absolute percentage error, «симметричное среднее абсолютное процентное отклонение»).
#
# В процессе поиска лучшей модели с помощью инструмента RandomizedSearchCV были обучены следующие модели с разными параметрами:
#
#
# * DecisionTreeRegressor()
# * LinearRegression
# * Ridge()
# * Lasso()
# * ElasticNet()
#
# Лучшей моделью стала модель деревья решений со следующими параметрами:

# %%
model_1

# %%
print(f'Метрика SMAPE на тестовой выборке: {smape(y_test1, y_pred1):.2f}')
# Out:
# Метрика SMAPE на тестовой выборке: 10.72

# %% [markdown]
# **Этап 1.6 Обучение модели**
#
# Были сделаны следующие выводы, почему модель деревьев решений лучше справилась:
#
# Деревья решений превзошли линейные модели в прогнозировании удовлетворенности сотрудников благодаря ключевым преимуществам:
#
# * Удовлетворенность сотрудников (job_satisfaction_rate) часто зависит от сложных нелинейных взаимодействий признаков       ("Высокая зарплата + гибкий график" дают больший эффект, чем сумма отдельных факторов). Решение дерева автоматически обнаруживает такие взаимодействия через ветвления.
# * Линейные модели предполагают линейную связь между признаками и целевой переменной, однако в нашем случае линейной зависимости почти нет
#
# **Этап 2.1 Загрузка данных**
#
# На данном этапе были успешно загружены три датафрейма: ***train_quit, test_features, test_target_quit*** для решения задачи 2.
#
# Были сделаны следующие выводы:
#
# * Тип данных везде корректен
# * Есть пропуски в датафрейме test_features в столбцах **dept** и **level**
#
#
#
# **Этап 2.2 Загрузка данных**
#
# Аналогично этапу 1.2 была выполнена проверка на пропуски, явные и неянвые дубликаты.
#
# Обнаружен пропуск:
# * test_features в столбцах dept и level
#
# Помимо этого, в столбце ***level*** уровень 'sinior' был переименован в 'senior'
#
# **Этап 2.3 Исследовательский анализ данных**
#
# Были исследованы все признаки датафреймов ***train_quit, test_features, test_target_quit***. Признаки по распределению походи на признаки пункта 1.3
#
# Кроме этого, были выполнены задачи:
#
# ***1. Был составлен портрет уволившегося сотрудника:***
#
# * Скорее всего, это сотрудник, который имеет **слабый** или **средний** уровень занятости
# * Наиболее вероятно, что это сотрудник из **отдела по продажам** или **технического отдела**, наименее вероятно, что это сотрудник из отдела **HR**
# * Скорее всего это сотрудник с зарплатой **менее 25000р**
# * Наиболее вероятно, что это сотрудник уровня **junior**
# * Почти точно это сотрудник, который **не получил повышение**
# * Наиболее вероятно, что этот мотрудник получил **оценку 3** у руководителя
# * Скорее всего этот сотрудник **не делал нарушений**
# * С большей вероятностью стаж этого сотрудника 1-2 года
#
# ***2. Была выполнена проверка связи удовлетворенности компанией и увольнения сотрудника***
#
# Оказалось, что связь между этими признаками действительно есть:
#
# * У уволившихся сотрудников в среднем уровень удовлетворенности меньше, чем у сотрудников, оставшихся работать в компании
#
# **Этап 2.4 Добавление нового входного признака**
#
# В датафреймы ***train_quit*** и ***test_features*** был добавлен новый столбец ***predicted_job_satisfaction*** (целевой признак задачи 1) путем использования лучшей модели для задачи 1.
#
# **Этап 2.5 Подготовка данных**
#
# Аналогично этапу 1.4 была выполнена подготовка данных. Были сделаны следующие выводы:
# * мультиколлинеарность отсутствует
# * признаки ***employmet_years***, ***salary***, ***pradicted_job_satusfaction*** умеренно связаны с целевым **quit**
# * признаки ***level***, ***supervisor_evaluation***, ***last_year_promo***, ***last_year_violations*** слабо связаны с целевым ***quit***
# * признак ***debt*** не связан с целевым ***quit***, возможно, его лучше не учитывать при обучении, будем опираться на метрики
#
# Также был реализован пайплайн для подготовки данных
#
# **Этап 2.6 Обучение модели**
#
# В процессе поиска лучшей модели с помощью инструмента RandomizedSearchCV были обучены следующие модели с разными параметрами:
#
# * KNeighborsClassifier();
# * DecisionTreeClassifier();
# * LogisticRegression();
# * SVC().
#
# Были перебраны различные методы подготовки данных (OneHotEncoder, OdrinalEncoder, StandardScaler, MinMaxScaler)
#
# Лучшей моделью стала модель деревья решений со следующими параметрами:

# %%
model_2
# Out:
# DecisionTreeClassifier(max_depth=7, max_features=8, min_samples_leaf=9,
#                        random_state=42)

# %%
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, y_test_pred)}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.9229013562101188

# %% [markdown]
# **Этап 2.7 Выводы**
#
# DecisionTreeClassifier показал лучший результат, потому что:
#
# * Хорошо работает с нелинейными зависимостями в данных (логистическая регрессия и линейный SVС менее гибкие).
#
# Дерево решений лучше адаптируется к сложным взаимосвязям в данных без жестких предположений о их природе.

# %% [markdown]
# **Реккомендации для бизнеса**

# %% [markdown]
# 1. Удержание сотрудников (снижение текучести кадров)
#
# Фокус на сотрудников с низкой удовлетворенностью.
# Так как предсказанный job_satisfaction_rate сильно связан с увольнениями, стоит внедрить систему раннего выявления "группы риска":
#
# * Регулярные опросы удовлетворенности (раз в квартал) с акцентом на сотрудников с оценкой ниже 0.5.
# * Персональные встречи с HR или руководителем для таких сотрудников.
#
# Улучшение условий для технологического отдела.
# Сотрудники этого отдела увольняются чаще остальных. Возможные меры:
# * Пересмотр зарплат (особенно для тех, кто получает меньше 25 000 ₽).
# * Гибкий график или удаленная работа для снижения нагрузки.
#
# Мотивация junior-сотрудников.
# Большинство увольнений приходится на новичков. Рекомендации:
#
# * Внедрение программ наставничества.
# * Четкий план карьерного роста в первые 6–12 месяцев работы.
#
# 2. Оптимизация зарплатной политики
#
#
# Пересмотр зарплат в отделах с высокой текучестью
# * Технологический отдел и младшие позиции (Junior) требуют особого внимания.
# * Внедрение грейдов для прозрачности зарплатных ожиданий.
#
# Бонусы за лояльность
#
# * Сотрудники со стажем 3+ лет реже увольняются. Можно предложить:
# * Ежегодные повышения на 5–10% для ключевых специалистов.
# * Доп. отпуск или премии за длительный стаж.
#
# 3. Профилактика нарушений
#
# 14% сотрудников допускали нарушения — это немало. Меры:
#
# * Четкие формулировки правил в трудовом договоре.
# * Тренинги по корпоративной этике.
# * Система предупреждений (а не только наказаний).
